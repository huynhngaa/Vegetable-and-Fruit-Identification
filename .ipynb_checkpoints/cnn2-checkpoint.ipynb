# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from IPython.display import HTML

# %%
# Set the constants
BATCH_SIZE = 32
IMAGE_SIZE = 224
CHANNELS=3
EPOCHS=10

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    r'hinh/train', 
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
val_ds =  tf.keras.preprocessing.image_dataset_from_directory(
     r'hinh/validation', 
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
test_ds =  tf.keras.preprocessing.image_dataset_from_directory(
     r'hinh/test', 
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 3077 files belonging to 36 classes.
# Found 351 files belonging to 36 classes.
# Found 359 files belonging to 36 classes.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
for image_batch, labels_batch in train_ds.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 224, 224, 3)
# [ 5  0 18 13 17 27 20 10 34 31  8 21  3 31 19 27 34 12 20 11 31 26 24 20
#  29  1 26  8 11  7 30 33]

# %%
plt.figure(figsize=(15, 15))
for image_batch, labels_batch in train_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./IMAGE_SIZE),
])

# %%
# augment data
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
#applying data augmentation to train dataset
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.map(
    lambda x, y: (data_augmentation(x, training=False), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.map(
    lambda x, y: (data_augmentation(x, training=False), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# build CNN model
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = len(class_names)

model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(25, kernel_size = (3,3), activation='relu', input_shape=input_shape),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(50,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(50,  kernel_size = (3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(50, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(50, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(50, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(50, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 224, 224, 3)         0
#
#  conv2d (Conv2D)             (32, 222, 222, 25)        700
#
#  max_pooling2d (MaxPooling2D  (32, 111, 111, 25)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 109, 109, 50)        11300
#
#  max_pooling2d_1 (MaxPooling  (32, 54, 54, 50)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 52, 52, 50)          22550
#
#  max_pooling2d_2 (MaxPooling  (32, 26, 26, 50)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 24, 24, 50)          22550
#
#  max_pooling2d_3 (MaxPooling  (32, 12, 12, 50)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 10, 10, 50)          22550
#
#  max_pooling2d_4 (MaxPooling  (32, 5, 5, 50)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 3, 3, 50)            22550
#
#  max_pooling2d_5 (MaxPooling  (32, 1, 1, 50)           0
#  2D)
#
#  flatten (Flatten)           (32, 50)                  0
#
#  dense (Dense)               (32, 50)                  2550
#
#  dense_1 (Dense)             (32, 36)                  1836
#
# =================================================================
# Total params: 106,586
# Trainable params: 106,586
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling
# 97/97 [==============================] - 128s 1s/step - loss: 1.0862 - accuracy: 0.6311 - val_loss: 0.7980 - val_accuracy: 0.7350
# Epoch 82/100
# 97/97 [==============================] - 127s 1s/step - loss: 1.0918 - accuracy: 0.6441 - val_loss: 0.7375 - val_accuracy: 0.7607
# Epoch 83/100
# 97/97 [==============================] - 129s 1s/step - loss: 1.0391 - accuracy: 0.6581 - val_loss: 0.6621 - val_accuracy: 0.7664
# Epoch 84/100
# 97/97 [==============================] - 119s 1s/step - loss: 1.0631 - accuracy: 0.6415 - val_loss: 0.6444 - val_accuracy: 0.8034
# Epoch 85/100
# 97/97 [==============================] - 128s 1s/step - loss: 1.1084 - accuracy: 0.6399 - val_loss: 0.5989 - val_accuracy: 0.8091
# Epoch 86/100
# 97/97 [==============================] - 129s 1s/step - loss: 1.0485 - accuracy: 0.6549 - val_loss: 0.6771 - val_accuracy: 0.7806
# Epoch 87/100
# 97/97 [==============================] - 131s 1s/step - loss: 1.0098 - accuracy: 0.6685 - val_loss: 0.7186 - val_accuracy: 0.7493
# Epoch 88/100
# 97/97 [==============================] - 142s 1s/step - loss: 1.0225 - accuracy: 0.6646 - val_loss: 0.7868 - val_accuracy: 0.7350
# Epoch 89/100
# 97/97 [==============================] - 138s 1s/step - loss: 1.0149 - accuracy: 0.6643 - val_loss: 0.8268 - val_accuracy: 0.7407
# Epoch 90/100
# 97/97 [==============================] - 131s 1s/step - loss: 1.0416 - accuracy: 0.6539 - val_loss: 0.7012 - val_accuracy: 0.7550
# Epoch 91/100
# 97/97 [==============================] - 123s 1s/step - loss: 0.9855 - accuracy: 0.6727 - val_loss: 0.7452 - val_accuracy: 0.7464
# Epoch 92/100
# 97/97 [==============================] - 122s 1s/step - loss: 1.0464 - accuracy: 0.6529 - val_loss: 0.8870 - val_accuracy: 0.7151
# Epoch 93/100
# 97/97 [==============================] - 125s 1s/step - loss: 0.9860 - accuracy: 0.6727 - val_loss: 0.7047 - val_accuracy: 0.7493
# Epoch 94/100
# 97/97 [==============================] - 124s 1s/step - loss: 0.9781 - accuracy: 0.6724 - val_loss: 0.6907 - val_accuracy: 0.7578
# Epoch 95/100
# 97/97 [==============================] - 123s 1s/step - loss: 0.9678 - accuracy: 0.6831 - val_loss: 0.7081 - val_accuracy: 0.7721
# Epoch 96/100
# 97/97 [==============================] - 123s 1s/step - loss: 0.9694 - accuracy: 0.6731 - val_loss: 0.6515 - val_accuracy: 0.7892
# Epoch 97/100
# 97/97 [==============================] - 121s 1s/step - loss: 0.9960 - accuracy: 0.6688 - val_loss: 0.6261 - val_accuracy: 0.8034
# Epoch 98/100
# 97/97 [==============================] - 123s 1s/step - loss: 0.9469 - accuracy: 0.6841 - val_loss: 0.7823 - val_accuracy: 0.7236
# Epoch 99/100
# 97/97 [==============================] - 123s 1s/step - loss: 0.9797 - accuracy: 0.6763 - val_loss: 0.6639 - val_accuracy: 0.7749
# Epoch 100/100
# 97/97 [==============================] - 119s 1s/step - loss: 0.9582 - accuracy: 0.6831 - val_loss: 0.6306 - val_accuracy: 0.7863

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Biểu đồ Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# Plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Biểu đồ Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
# save model
model.save("cnn_model.h5")
print("Model saved!")
# Out:
# Model saved!
